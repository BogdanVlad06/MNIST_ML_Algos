# %%
import os 
import cv2
import tensorflow.keras as keras
import tensorflow.keras.layers as layer
import numpy as np

# %% [markdown]
# ## Load data

# %%
mnist_path = 'C:/Users/gurau/Desktop/Jupyter_Lab/3. Computer Vision/MNIST/mnist-png'

def load_data(data, folder_path):
    data_path = os.path.join(folder_path, data)
    images, labels = [], []
    for label in os.listdir(data_path):
        label_path = os.path.join(data_path, label)
        for file in os.listdir(label_path):
            file_path = os.path.join(label_path, file)
            img = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
            images.append(img)
            labels.append(int(label))
    return np.array(images), np.array(labels)

# %%
train_i, train_l = load_data('train', mnist_path)
test_i, test_l = load_data('test', mnist_path)

# %% [markdown]
# ## Preprocessing

# %%
train_i, test_i = train_i.reshape(-1, 28*28).astype('float32'), test_i.reshape(-1, 28*28).astype('float32')
train_i, test_i = train_i / 255., test_i / 255.

# %% [markdown]
# ### Shuffle and Split training data

# %%
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
train_X, train_y = shuffle(train_i, train_l, random_state=42)

# %%
train_X.shape, train_y.shape
# Out:
# ((60000, 784), (60000,))

# %% [markdown]
# ## Artificial Neural Network structure:

# %%
def ANN_MODEL(in_shape):
    model = keras.Sequential()
    
    model.add(layer.Input(shape=(in_shape,)))

    model.add(layer.Dense(128, activation='relu'))
    model.add(layer.Dense(64, activation= 'relu'))
    
    model.add(layer.Dense(10, activation='softmax'))

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
ann_model =  ANN_MODEL(train_i.shape[1])
ann_model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_18 (Dense)                │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_19 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_20 (Dense)                │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,386 (427.29 KB)
#  Trainable params: 109,386 (427.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = ann_model.fit(train_X, train_y, epochs=30, batch_size=128, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8086 - loss: 0.6776 - val_accuracy: 0.9492 - val_loss: 0.1827
# Epoch 2/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9512 - loss: 0.1649 - val_accuracy: 0.9628 - val_loss: 0.1298
# Epoch 3/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9654 - loss: 0.1150 - val_accuracy: 0.9686 - val_loss: 0.1101
# Epoch 4/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9766 - loss: 0.0796 - val_accuracy: 0.9691 - val_loss: 0.1069
# Epoch 5/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9817 - loss: 0.0618 - val_accuracy: 0.9720 - val_loss: 0.0962
# Epoch 6/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9845 - loss: 0.0512 - val_accuracy: 0.9707 - val_loss: 0.1003
# Epoch 7/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9879 - loss: 0.0403 - val_accuracy: 0.9743 - val_loss: 0.0862
# Epoch 8/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9917 - loss: 0.0303 - val_accuracy: 0.9726 - val_loss: 0.0972
# Epoch 9/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9929 - loss: 0.0248 - val_accuracy: 0.9743 - val_loss: 0.0921
# Epoch 10/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9939 - loss: 0.0221 - val_accuracy: 0.9737 - val_loss: 0.0943
# Epoch 11/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9958 - loss: 0.0161 - val_accuracy: 0.9762 - val_loss: 0.0943
# Epoch 12/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9961 - loss: 0.0143 - val_accuracy: 0.9753 - val_loss: 0.1000
# Epoch 13/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9970 - loss: 0.0112 - val_accuracy: 0.9742 - val_loss: 0.1040
# Epoch 14/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9969 - loss: 0.0105 - val_accuracy: 0.9753 - val_loss: 0.1029
# Epoch 15/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9965 - loss: 0.0112 - val_accuracy: 0.9756 - val_loss: 0.1003
# Epoch 16/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9983 - loss: 0.0072 - val_accuracy: 0.9736 - val_loss: 0.1192
# Epoch 17/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9949 - loss: 0.0157 - val_accuracy: 0.9777 - val_loss: 0.0977
# Epoch 18/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9993 - loss: 0.0043 - val_accuracy: 0.9775 - val_loss: 0.1049
# Epoch 19/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9982 - loss: 0.0061 - val_accuracy: 0.9761 - val_loss: 0.1146
# Epoch 20/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9971 - loss: 0.0085 - val_accuracy: 0.9773 - val_loss: 0.1100
# Epoch 21/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9989 - loss: 0.0044 - val_accuracy: 0.9766 - val_loss: 0.1136
# Epoch 22/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9980 - loss: 0.0067 - val_accuracy: 0.9692 - val_loss: 0.1629
# Epoch 23/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9966 - loss: 0.0101 - val_accuracy: 0.9737 - val_loss: 0.1275
# Epoch 24/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9970 - loss: 0.0082 - val_accuracy: 0.9791 - val_loss: 0.1128
# Epoch 25/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9987 - loss: 0.0039 - val_accuracy: 0.9773 - val_loss: 0.1289
# Epoch 26/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9994 - loss: 0.0030 - val_accuracy: 0.9767 - val_loss: 0.1274
# Epoch 27/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9976 - loss: 0.0063 - val_accuracy: 0.9773 - val_loss: 0.1301
# Epoch 28/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9979 - loss: 0.0067 - val_accuracy: 0.9791 - val_loss: 0.1126
# Epoch 29/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9999 - loss: 8.8504e-04 - val_accuracy: 0.9778 - val_loss: 0.1197
# Epoch 30/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9999 - loss: 4.7560e-04 - val_accuracy: 0.9803 - val_loss: 0.1150

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
ann_model.evaluate(test_i, test_l)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9840 - loss: 0.0807
# [0.11225738376379013, 0.9793000221252441]

# %% [markdown]
# Key observations: DO NOT make ___labels___ dtype **float**!
