# %% [markdown]
# ## Imports

# %%
import os 
import cv2
import tensorflow.keras as keras
import tensorflow.keras.layers as layer
import numpy as np

# %% [markdown]
# ## Load data

# %%
mnist_path = 'C:/Users/gurau/Desktop/Jupyter_Lab/3. Computer Vision/MNIST/mnist-png'

def load_data(data, folder_path):
    data_path = os.path.join(folder_path, data)
    images, labels = [], []
    for label in os.listdir(data_path):
        label_path = os.path.join(data_path, label)
        for file in os.listdir(label_path):
            file_path = os.path.join(label_path, file)
            img = cv2.imread(file_path, cv2.IMREAD_GRAYSCALE)
            images.append(img)
            labels.append(int(label))
    return np.array(images), np.array(labels)

# %%
train_i, train_l = load_data('train', mnist_path)
test_i, test_l = load_data('test', mnist_path)

# %% [markdown]
# ### Shuffle and Split training data

# %%
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
train_X, train_y = shuffle(train_i, train_l, random_state=42)

# %%
train_X.shape[1:], train_y.shape
# Out:
# ((28, 28), (60000,))

# %% [markdown]
# ## Artificial Neural Network structure:

# %%
def ANN_MODEL(in_shape):
    model = keras.Sequential(name='MNIST_ANN_with_preprocessing_layers')
    
    model.add(layer.Input(shape=(in_shape)))
    
    model.add(layer.Flatten())
    model.add(layer.Rescaling(scale=1./255.))
    model.add(layer.Dense(128, activation='relu'))
    model.add(layer.Dense(64, activation= 'relu'))
    
    model.add(layer.Dense(10, activation='softmax'))

    model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

    return model

# %%
ann_model =  ANN_MODEL(train_i.shape[1:])
ann_model.summary()
# Out:
# Model: "MNIST_ANN_with_preprocessing_layers"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten_1 (Flatten)             │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling_1 (Rescaling)         │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,386 (427.29 KB)
#  Trainable params: 109,386 (427.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = ann_model.fit(train_X, train_y, epochs=30, batch_size=128, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7999 - loss: 0.6836 - val_accuracy: 0.9467 - val_loss: 0.1856
# Epoch 2/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9523 - loss: 0.1630 - val_accuracy: 0.9628 - val_loss: 0.1325
# Epoch 3/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9669 - loss: 0.1104 - val_accuracy: 0.9681 - val_loss: 0.1078
# Epoch 4/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9761 - loss: 0.0803 - val_accuracy: 0.9690 - val_loss: 0.1003
# Epoch 5/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9816 - loss: 0.0619 - val_accuracy: 0.9740 - val_loss: 0.0885
# Epoch 6/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9869 - loss: 0.0471 - val_accuracy: 0.9752 - val_loss: 0.0853
# Epoch 7/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9887 - loss: 0.0371 - val_accuracy: 0.9741 - val_loss: 0.0895
# Epoch 8/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9916 - loss: 0.0285 - val_accuracy: 0.9724 - val_loss: 0.0968
# Epoch 9/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9942 - loss: 0.0222 - val_accuracy: 0.9719 - val_loss: 0.1002
# Epoch 10/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9942 - loss: 0.0196 - val_accuracy: 0.9738 - val_loss: 0.0890
# Epoch 11/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9954 - loss: 0.0162 - val_accuracy: 0.9765 - val_loss: 0.0868
# Epoch 12/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9966 - loss: 0.0133 - val_accuracy: 0.9766 - val_loss: 0.0951
# Epoch 13/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9957 - loss: 0.0128 - val_accuracy: 0.9750 - val_loss: 0.1016
# Epoch 14/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9962 - loss: 0.0126 - val_accuracy: 0.9765 - val_loss: 0.1021
# Epoch 15/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9984 - loss: 0.0071 - val_accuracy: 0.9786 - val_loss: 0.0944
# Epoch 16/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9988 - loss: 0.0053 - val_accuracy: 0.9748 - val_loss: 0.1098
# Epoch 17/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9981 - loss: 0.0071 - val_accuracy: 0.9746 - val_loss: 0.1100
# Epoch 18/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9954 - loss: 0.0139 - val_accuracy: 0.9743 - val_loss: 0.1200
# Epoch 19/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9968 - loss: 0.0107 - val_accuracy: 0.9780 - val_loss: 0.1011
# Epoch 20/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9978 - loss: 0.0070 - val_accuracy: 0.9765 - val_loss: 0.1135
# Epoch 21/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9972 - loss: 0.0078 - val_accuracy: 0.9789 - val_loss: 0.1011
# Epoch 22/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9996 - loss: 0.0022 - val_accuracy: 0.9780 - val_loss: 0.1041
# Epoch 23/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9999 - loss: 9.6260e-04 - val_accuracy: 0.9792 - val_loss: 0.1002
# Epoch 24/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9969 - loss: 0.0098 - val_accuracy: 0.9753 - val_loss: 0.1204
# Epoch 25/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9975 - loss: 0.0074 - val_accuracy: 0.9749 - val_loss: 0.1372
# Epoch 26/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9976 - loss: 0.0075 - val_accuracy: 0.9743 - val_loss: 0.1395
# Epoch 27/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9977 - loss: 0.0064 - val_accuracy: 0.9768 - val_loss: 0.1192
# Epoch 28/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9996 - loss: 0.0021 - val_accuracy: 0.9807 - val_loss: 0.1113
# Epoch 29/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9991 - loss: 0.0030 - val_accuracy: 0.9787 - val_loss: 0.1180
# Epoch 30/30
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9982 - loss: 0.0057 - val_accuracy: 0.9772 - val_loss: 0.1394

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# %%
ann_model.evaluate(test_i, test_l)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9833 - loss: 0.0818
# [0.12286097556352615, 0.9753000140190125]
